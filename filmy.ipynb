# %% [markdown]
# <a href="https://colab.research.google.com/github/hynekmayrhofer1/Hynek-Mayrhofer/blob/main/filmy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# --------------------------
# 1) Databáze filmů
# --------------------------

movies = [
    ("The Shawshank Redemption", 1994, 9.3),
    ("The Godfather", 1972, 9.2),
    ("The Dark Knight", 2008, 9.0),
    ("Pulp Fiction", 1994, 8.9),
    ("Forrest Gump", 1994, 8.8),
    ("Fight Club", 1999, 8.8),
    ("Inception", 2010, 8.8),
    ("The Matrix", 1999, 8.7),
    ("Goodfellas", 1990, 8.7),
    ("The Silence of the Lambs", 1991, 8.6)
]

# %%
after_2000 = [m for m in movies if m[1] > 2000]
print("Filmy po roce 2000:")
for m in after_2000:
    print(m)
# Out:
# Filmy po roce 2000:
# ('The Dark Knight', 2008, 9.0)
# ('Inception', 2010, 8.8)

# %%
top_movies = [m for m in movies if m[2] >= 9.0]
print("\nNejlépe hodnocené filmy (9.0+):")
for m in top_movies:
    print(m)
# Out:
# Nejlépe hodnocené filmy (9.0+):
# ('The Shawshank Redemption', 1994, 9.3)
# ('The Godfather', 1972, 9.2)
# ('The Dark Knight', 2008, 9.0)

# %%
sorted_by_year = sorted(movies, key=lambda m: m[1])
print("\nŘazení podle roku:")
for m in sorted_by_year:
    print(m)
# Out:
# Řazení podle roku:
# ('The Godfather', 1972, 9.2)
# ('Goodfellas', 1990, 8.7)
# ('The Silence of the Lambs', 1991, 8.6)
# ('The Shawshank Redemption', 1994, 9.3)
# ('Pulp Fiction', 1994, 8.9)
# ('Forrest Gump', 1994, 8.8)
# ('Fight Club', 1999, 8.8)
# ('The Matrix', 1999, 8.7)
# ('The Dark Knight', 2008, 9.0)
# ('Inception', 2010, 8.8)

# %%
sorted_by_rating = sorted(movies, key=lambda m: m[2], reverse=True)
print("\nŘazení podle hodnocení:")
for m in sorted_by_rating:
    print(m)
# Out:
# Řazení podle hodnocení:
# ('The Shawshank Redemption', 1994, 9.3)
# ('The Godfather', 1972, 9.2)
# ('The Dark Knight', 2008, 9.0)
# ('Pulp Fiction', 1994, 8.9)
# ('Forrest Gump', 1994, 8.8)
# ('Fight Club', 1999, 8.8)
# ('Inception', 2010, 8.8)
# ('The Matrix', 1999, 8.7)
# ('Goodfellas', 1990, 8.7)
# ('The Silence of the Lambs', 1991, 8.6)

# %%
ratings = [m[2] for m in movies]

print("\nPopisné statistiky:")
print("Počet filmů:", len(ratings))
print("Průměrné hodnocení:", np.mean(ratings))
print("Medián:", np.median(ratings))
print("Minimum:", np.min(ratings))
print("Maximum:", np.max(ratings))
# Out:
# Popisné statistiky:
# Počet filmů: 10
# Průměrné hodnocení: 8.879999999999999
# Medián: 8.8
# Minimum: 8.6
# Maximum: 9.3

# %%
plt.hist(ratings, bins=5, edgecolor='black')
plt.title("Histogram hodnocení filmů")
plt.xlabel("Hodnocení")
plt.ylabel("Počet filmů")
plt.show()
